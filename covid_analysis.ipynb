# %%
print("Hello, COVID Analysis!")
# Out:
# Hello, COVID Analysis!

# %%
import pandas as pd
df = pd.read_csv("owid-covid-data.csv")
egypt_df = df[df["location"] == "Egypt"]

# %%
egypt_df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
egypt_df.head()
# Out:
# Empty DataFrame
# ...

# %%
df["location"].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda'], dtype=object)

# %%
"Egypt" in df["location"].unique()
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv("owid-covid-data.csv")
df["location"].unique()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("owid-covid-data.csv")
#       4 df["location"].unique()
#
# File F:\Anaconda\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv("owid-covid-data.csv")
df["location"].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
# ...

# %%
egypt_df = df[df["location"] == "Egypt"]

# %%
egypt_df.head()
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 105484      EGY    Africa    Egypt  2020-01-05          0.0        0.0
# 105485      EGY    Africa    Egypt  2020-01-06          0.0        0.0
# 105486      EGY    Africa    Egypt  2020-01-07          0.0        0.0
# 105487      EGY    Africa    Egypt  2020-01-08          0.0        0.0
# 105488      EGY    Africa    Egypt  2020-01-09          0.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 105484                 NaN           0.0         0.0                  NaN
# 105485                 NaN           0.0         0.0                  NaN
# 105486                 NaN           0.0         0.0                  NaN
# 105487                 NaN           0.0         0.0                  NaN
# 105488                 NaN           0.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
egypt_df.loc[:, "date"] = pd.to_datetime(egypt_df["date"])

# %%
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases"], color='blue')
plt.title("Daily New COVID-19 Cases in Egypt")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.grid(True)
plt.show()

# %%
# استيراد المكتبات
import pandas as pd
import matplotlib.pyplot as plt

# تحميل البيانات من ملف CSV
df = pd.read_csv("owid-covid-data.csv")

# فلترة بيانات مصر فقط
egypt_df = df[df["location"] == "Egypt"].copy()  # .copy() لحل تحذير الـ Warning

# تحويل عمود التاريخ إلى datetime
egypt_df["date"] = pd.to_datetime(egypt_df["date"])

# رسم الحالات اليومية
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases"], color='blue')
plt.title("Daily New COVID-19 Cases in Egypt")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.grid(True)
plt.show()

# رسم الوفيات اليومية
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_deaths"], color='red')
plt.title("Daily COVID-19 Deaths in Egypt")
plt.xlabel("Date")
plt.ylabel("New Deaths")
plt.grid(True)
plt.show()

# %%
# 1️⃣ أعلى يوم إصابات
max_cases = egypt_df[egypt_df["new_cases"] == egypt_df["new_cases"].max()]
print("📅 أعلى يوم إصابات:")
print(max_cases[["date", "new_cases"]])
print()

# 2️⃣ أعلى يوم وفيات
max_deaths = egypt_df[egypt_df["new_deaths"] == egypt_df["new_deaths"].max()]
print("📅 أعلى يوم وفيات:")
print(max_deaths[["date", "new_deaths"]])
print()

# 3️⃣ إجمالي عدد الإصابات في مصر
total_cases = egypt_df["total_cases"].max()
print(f"📊 إجمالي الإصابات في مصر: {int(total_cases):,}")

# 4️⃣ إجمالي عدد الوفيات في مصر
total_deaths = egypt_df["total_deaths"].max()
print(f"💀 إجمالي الوفيات في مصر: {int(total_deaths):,}")
# Out:
# 📅 أعلى يوم إصابات:
#              date  new_cases
# 106247 2022-02-06    15872.0
#
# 📅 أعلى يوم وفيات:
#              date  new_deaths
# 105652 2020-06-21       622.0
#
# 📊 إجمالي الإصابات في مصر: 516,023
# 💀 إجمالي الوفيات في مصر: 24,830

# %%
# نحسب المتوسط المتحرك لـ 7 أيام للحالات اليومية
egypt_df["new_cases_ma"] = egypt_df["new_cases"].rolling(window=7).mean()

# رسم الحالات والمتوسط المتحرك معًا
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases"], color='lightblue', label='Daily New Cases')
plt.plot(egypt_df["date"], egypt_df["new_cases_ma"], color='blue', label='7-day Moving Average', linewidth=2)
plt.title("Daily COVID-19 Cases in Egypt with 7-day Moving Average")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.legend()
plt.grid(True)
plt.show()

# %%
# رسم تطور إجمالي الحالات
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["total_cases"], color='darkorange')
plt.title("Total COVID-19 Cases in Egypt Over Time")
plt.xlabel("Date")
plt.ylabel("Total Cases")
plt.grid(True)
plt.show()

# رسم تطور إجمالي الوفيات
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["total_deaths"], color='darkred')
plt.title("Total COVID-19 Deaths in Egypt Over Time")
plt.xlabel("Date")
plt.ylabel("Total Deaths")
plt.grid(True)
plt.show()

# %%
egypt_df["new_cases_MA7"] = egypt_df["new_cases"].rolling(window=7).mean()
egypt_df["new_deaths_MA7"] = egypt_df["new_deaths"].rolling(window=7).mean()

plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases_MA7"], color='green')
plt.title("7-Day Moving Average of Daily New Cases")
plt.xlabel("Date")
plt.ylabel("Cases")
plt.grid(True)
plt.show()

plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_deaths_MA7"], color='purple')
plt.title("7-Day Moving Average of Daily New Deaths")
plt.xlabel("Date")
plt.ylabel("Deaths")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# حساب الحالات اليومية الجديدة
egypt_df["new_cases"] = egypt_df["total_cases"].diff().fillna(0)
egypt_df["new_deaths"] = egypt_df["total_deaths"].diff().fillna(0)

# حساب المتوسط المتحرك 7 أيام
egypt_df["new_cases_MA7"] = egypt_df["new_cases"].rolling(window=7).mean()
egypt_df["new_deaths_MA7"] = egypt_df["new_deaths"].rolling(window=7).mean()

# رسم الحالات اليومية الجديدة والمتوسط المتحرك
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases"], label="Daily New Cases", color="skyblue")
plt.plot(egypt_df["date"], egypt_df["new_cases_MA7"], label="7-Day Moving Average", color="blue", linewidth=3)
plt.title("Daily New COVID-19 Cases in Egypt")
plt.xlabel("Date")
plt.ylabel("Number of Cases")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_deaths"], label="Daily New Deaths", color="lightcoral")
plt.plot(egypt_df["date"], egypt_df["new_deaths_MA7"], label="7-Day Moving Average", color="red", linewidth=3)
plt.title("Daily New COVID-19 Deaths in Egypt")
# Out:
# Text(0.5, 1.0, 'Daily New COVID-19 Deaths in Egypt')

# %%
pip install prophet
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.3 MB 1.0 MB/s eta 0:00:13
#    -- ------------------------------------- 0.8/13.3 MB 1.0 MB/s eta 0:00:13
#    --- ------------------------------------ 1.0/13.3 MB 1.0 MB/s eta 0:00:13
#    --- ------------------------------------ 1.0/13.3 MB 1.0 MB/s eta 0:00:13
#    --- ------------------------------------ 1.3/13.3 MB 883.4 kB/s eta 0:00:14
#    --- ------------------------------------ 1.3/13.3 MB 883.4 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.6/13.3 MB 830.6 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.6/13.3 MB 830.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.8/13.3 MB 768.4 kB/s eta 0:00:15
# ...

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# تجهيز البيانات للنموذج
df_prophet = egypt_df[["date", "new_cases"]].rename(columns={"date": "ds", "new_cases": "y"})

# تأكد أن ما فيش قيم سالبة أو نواقص في y
df_prophet = df_prophet[df_prophet["y"] >= 0]

# إنشاء نموذج Prophet
model = Prophet()

# تدريب النموذج
model.fit(df_prophet)

# إنشاء بيانات للتنبؤ ل30 يوم قادم
future = model.make_future_dataframe(periods=30)

# التنبؤ
forecast = model.predict(future)

# عرض نتائج التنبؤ
model.plot(forecast)
plt.title("COVID-19 New Cases Forecast for Egypt (Next 30 Days)")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.show()
# Out:
# 11:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 11:24:02 - cmdstanpy - INFO - Chain [1] done processing

# %%
# حساب معدل النمو اليومي (%)
egypt_df["growth_rate"] = egypt_df["new_cases"] / egypt_df["total_cases"].shift(1) * 100
egypt_df["growth_rate"] = egypt_df["growth_rate"].fillna(0)

# رسم معدل النمو
plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["growth_rate"], color='purple')
plt.title("Daily Growth Rate (%) of COVID-19 Cases in Egypt")
plt.xlabel("Date")
plt.ylabel("Growth Rate (%)")
plt.grid(True)
plt.show()

# %%
egypt_df["CFR"] = (egypt_df["total_deaths"] / egypt_df["total_cases"]) * 100

plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["CFR"], color='brown')
plt.title("Case Fatality Rate (CFR) Over Time in Egypt")
plt.xlabel("Date")
plt.ylabel("CFR (%)")
plt.grid(True)
plt.show()

# %%
from scipy.signal import find_peaks

# العثور على ذروات في الحالات الجديدة
peaks, _ = find_peaks(egypt_df["new_cases"], distance=7)  # مسافة 7 أيام بين الذروات

plt.figure(figsize=(14,6))
plt.plot(egypt_df["date"], egypt_df["new_cases"], label="Daily New Cases")
plt.plot(egypt_df["date"].iloc[peaks], egypt_df["new_cases"].iloc[peaks], "rx", label="Peaks")
plt.title("Daily New COVID-19 Cases with Peaks")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.legend()
plt.grid(True)
plt.show()
